# %% [markdown]
# ## Google Cloud Storage

# %% [markdown]
# ### Access Control:
# #### Fine-grained:
#     Object access is controlled through both bucket-level (IAM) and object-level permissions (ACLs), allowing access to be specified for individual objects.
# #### Uniform:
#     Object access is controlled entirely through bucket-level permissions (IAM), ensuring uniform access to all objects in a bucket.
